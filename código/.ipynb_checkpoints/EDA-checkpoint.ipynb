# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ec = pd.read_csv("C:/Users/mathe/Documents/projetos/Analise de dados/projeto-19/E-Commerce-Sales/dashboard/archive/E-Commerce Sales Analytics 1.0 .csv")

# %%
ec.head()
# Out:
#    Unnamed: 0  order_id  order_date  customer_id product_category region  \
# 0           0     10001  2022-01-01         1102           Beauty  South
# 1           1     10002  2022-02-01         1435         Clothing  South
# 2           2     10003  2022-03-01         1860           Beauty   East
# 3           3     10004  2022-04-01         1270      Electronics   West
# 4           4     10005  2022-05-01         1106         Clothing   West
#
#    quantity  unit_price  discount payment_method  delivery_days  \
# 0         7      373.65      0.28         Wallet             10
# 1         7       47.74      0.09           Card              6
# 2         3      311.28      0.31            COD              6
# 3         5      524.47      0.02         Wallet              6
# 4         5      139.87      0.33         Wallet              4
#
#    customer_rating  revenue
# 0              4.7  1883.20
# 1              3.9   304.10
# 2              2.5   644.35
# ...

# %%
ec.tail()
# Out:
#       Unnamed: 0  order_id  order_date  customer_id product_category region  \
# 4995        4995     14996  2035-05-09         1289         Clothing   West
# 4996        4996     14997  2035-06-09         1294           Beauty  North
# 4997        4997     14998  2035-07-09         1450           Beauty   West
# 4998        4998     14999  2035-08-09         1903      Electronics  South
# 4999        4999     15000  2035-09-09         1214             Home   East
#
#       quantity  unit_price  discount payment_method  delivery_days  \
# 4995         2      371.74      0.27            COD              3
# 4996         3      553.67      0.14            COD             11
# 4997         3       77.22      0.24         Wallet              6
# 4998         4      138.41      0.21            COD              4
# 4999         7      231.58      0.34            COD              5
#
#       customer_rating  revenue
# 4995              2.3   542.74
# 4996              2.2  1428.47
# ...

# %%
ec[['quantity', 'unit_price', 'discount', 'revenue']].describe()
# Out:
#           quantity   unit_price     discount      revenue
# count  5000.000000  5000.000000  5000.000000  5000.000000
# mean      4.044800   308.418774     0.179984  1021.955148
# std       2.020398   169.259369     0.101404   825.584219
# min       1.000000    15.150000     0.000000    11.210000
# 25%       2.000000   161.895000     0.090000   354.527500
# 50%       4.000000   309.890000     0.180000   796.650000
# 75%       6.000000   455.557500     0.270000  1515.690000
# max       7.000000   599.960000     0.350000  4119.330000

# %%
sns.boxplot(data=ec, x='quantity')
# Out:
# <Axes: xlabel='quantity'>

# %%
sns.boxplot(data=ec, x='unit_price')
# Out:
# <Axes: xlabel='unit_price'>

# %%
sns.boxplot(data=ec, x='discount')
# Out:
# <Axes: xlabel='discount'>

# %%
sns.boxplot(data=ec, x='revenue')
# Out:
# <Axes: xlabel='revenue'>
