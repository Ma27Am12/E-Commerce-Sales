# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ec = pd.read_csv("C:/Users/mathe/Documents/projetos/Analise de dados/projeto-19/E-Commerce-Sales/dashboard/archive/E-Commerce Sales Analytics 1.0 .csv")

# %%
ec.head()
# Out:
#    Unnamed: 0  order_id  order_date  customer_id product_category region  \
# 0           0     10001  2022-01-01         1102           Beauty  South
# 1           1     10002  2022-02-01         1435         Clothing  South
# 2           2     10003  2022-03-01         1860           Beauty   East
# 3           3     10004  2022-04-01         1270      Electronics   West
# 4           4     10005  2022-05-01         1106         Clothing   West
#
#    quantity  unit_price  discount payment_method  delivery_days  \
# 0         7      373.65      0.28         Wallet             10
# 1         7       47.74      0.09           Card              6
# 2         3      311.28      0.31            COD              6
# 3         5      524.47      0.02         Wallet              6
# 4         5      139.87      0.33         Wallet              4
#
#    customer_rating  revenue
# 0              4.7  1883.20
# 1              3.9   304.10
# 2              2.5   644.35
# ...

# %%
ec.tail()
# Out:
#       Unnamed: 0  order_id  order_date  customer_id product_category region  \
# 4995        4995     14996  2035-05-09         1289         Clothing   West
# 4996        4996     14997  2035-06-09         1294           Beauty  North
# 4997        4997     14998  2035-07-09         1450           Beauty   West
# 4998        4998     14999  2035-08-09         1903      Electronics  South
# 4999        4999     15000  2035-09-09         1214             Home   East
#
#       quantity  unit_price  discount payment_method  delivery_days  \
# 4995         2      371.74      0.27            COD              3
# 4996         3      553.67      0.14            COD             11
# 4997         3       77.22      0.24         Wallet              6
# 4998         4      138.41      0.21            COD              4
# 4999         7      231.58      0.34            COD              5
#
#       customer_rating  revenue
# 4995              2.3   542.74
# 4996              2.2  1428.47
# ...

# %%
ec[['quantity', 'unit_price', 'discount', 'revenue']].describe()
# Out:
#           quantity   unit_price     discount      revenue
# count  5000.000000  5000.000000  5000.000000  5000.000000
# mean      4.044800   308.418774     0.179984  1021.955148
# std       2.020398   169.259369     0.101404   825.584219
# min       1.000000    15.150000     0.000000    11.210000
# 25%       2.000000   161.895000     0.090000   354.527500
# 50%       4.000000   309.890000     0.180000   796.650000
# 75%       6.000000   455.557500     0.270000  1515.690000
# max       7.000000   599.960000     0.350000  4119.330000

# %%
sns.boxplot(data=ec, x='quantity')
# Out:
# <Axes: xlabel='quantity'>

# %%
sns.boxplot(data=ec, x='unit_price')
# Out:
# <Axes: xlabel='unit_price'>

# %%
sns.boxplot(data=ec, x='discount')
# Out:
# <Axes: xlabel='discount'>

# %%
sns.boxplot(data=ec, x='revenue')
# Out:
# <Axes: xlabel='revenue'>

# %%
revenue_Outliers = ec[ec['revenue'] > 3000 ]

# %%
revenue_Outliers.head()
# Out:
#     Unnamed: 0  order_id  order_date  customer_id product_category region  \
# 39          39     10040  2022-09-02         1474             Home  North
# 66          66     10067  2022-08-03         1600             Home  North
# 69          69     10070  2022-11-03         1241           Beauty   East
# 89          89     10090  2022-03-31         1387      Electronics  South
# 97          97     10098  2022-08-04         1702      Electronics  North
#
#     quantity  unit_price  discount payment_method  delivery_days  \
# 39         7      584.36      0.11           Card              6
# 66         6      553.72      0.07           Card              7
# 69         7      567.75      0.16           Card              1
# 89         6      588.62      0.12           Card             10
# 97         6      576.02      0.07           Card              8
#
#     customer_rating  revenue
# 39              1.3  3640.56
# 66              4.2  3089.76
# 69              4.5  3338.37
# ...

# %%
revenue_Outliers.tail()
# Out:
#       Unnamed: 0  order_id  order_date  customer_id product_category region  \
# 4728        4728     14729  2034-12-12         1086         Clothing   East
# 4850        4850     14851  2035-04-13         1398             Home   West
# 4883        4883     14884  2035-05-16         1146      Electronics  South
# 4893        4893     14894  2035-05-26         1286           Beauty   West
# 4980        4980     14981  2035-08-21         1374             Home  North
#
#       quantity  unit_price  discount payment_method  delivery_days  \
# 4728         7      514.98      0.01           Card              1
# 4850         7      464.44      0.00           Card             10
# 4883         7      583.31      0.00           Card              5
# 4893         7      529.36      0.16            COD              9
# 4980         7      525.18      0.10           Card              8
#
#       customer_rating  revenue
# 4728              3.8  3568.81
# 4850              2.8  3251.08
# ...

# %%
sns.histplot(data=ec, x='quantity', bins=5)
# Out:
# <Axes: xlabel='quantity', ylabel='Count'>

# %%
sns.histplot(data=ec, x='unit_price', bins=10)
# Out:
# <Axes: xlabel='unit_price', ylabel='Count'>

# %%
sns.histplot(data=ec, x='discount', bins=10)
# Out:
# <Axes: xlabel='discount', ylabel='Count'>

# %%
sns.histplot(data=ec, x='revenue', bins=10)
# Out:
# <Axes: xlabel='revenue', ylabel='Count'>

# %%
sns.countplot(data=ec, x='product_category')
# Out:
# <Axes: xlabel='product_category', ylabel='count'>

# %%
sns.countplot(data=ec, x='payment_method')
# Out:
# <Axes: xlabel='payment_method', ylabel='count'>

# %%
sns.barplot(data=ec, x='product_category', y='revenue')
# Out:
# <Axes: xlabel='product_category', ylabel='revenue'>

# %%
sns.barplot(data=ec, x='product_category', y='unit_price')
# Out:
# <Axes: xlabel='product_category', ylabel='unit_price'>

# %%
sns.barplot(data=ec, x='product_category', y='quantity')
# Out:
# <Axes: xlabel='product_category', ylabel='quantity'>

# %%
sns.barplot(data=ec, x='payment_method', y='revenue')
# Out:
# <Axes: xlabel='payment_method', ylabel='revenue'>

# %%
sns.barplot(data=ec, x='payment_method', y='revenue', hue='product_category')
# Out:
# <Axes: xlabel='payment_method', ylabel='revenue'>
